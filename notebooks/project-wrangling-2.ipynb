# %% [markdown]
# # ABE 516 Project Data Wrangling 2

# %% [markdown]
# ## Nitrate Concentration Data

# %%
#imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import numpy as np
import datetime as dt

# allow plots to appear directly in the notebook
# %matplotlib inline

# %% [markdown]
# **Read in Data**

# %%
wq_raw = pd.read_csv("SH_WQ_raw_2022.csv")
wq_raw.head()
# Out:
#   Case Number         Scientist Matrix Project Name Submission Date Comments  \
# 0     22x0132  Natalia Rogovska  Water      Shearer       4/12/2022      NaN
# 1     22x0132  Natalia Rogovska  Water      Shearer       4/12/2022      NaN
# 2     22x0132  Natalia Rogovska  Water      Shearer       4/12/2022      NaN
# 3     22x0132  Natalia Rogovska  Water      Shearer       4/12/2022      NaN
# 4     22x0132  Natalia Rogovska  Water      Shearer       4/12/2022      NaN
#
#   Units Sample Number   Site ID  Bottle No  NO3-N
# 0  mg/L   22x0132-001  SH210101        1.0    3.3
# 1  mg/L   22x0132-002  SH210102        2.0    0.4
# 2  mg/L   22x0132-003  SH210103        3.0  < 0.3
# 3  mg/L   22x0132-004  SH210104        4.0    6.1
# 4  mg/L   22x0132-005  SH210105        5.0    5.8

# %% [markdown]
# **Change Data Types**

# %%
wq_raw.dtypes
# Out:
# Case Number         object
# Scientist           object
# Matrix              object
# Project Name        object
# Submission Date     object
# Comments            object
# Units               object
# Sample Number       object
# Site ID             object
# Bottle No          float64
# NO3-N               object
# dtype: object

# %%
wq_raw = wq_raw.astype({"Case Number":"string",
                       "Scientist":"string",
                       "Matrix":"string",
                       "Project Name":"string", 
                       "Comments":"string",
                       "Units":"string",
                       "Sample Number":"string",
                       "Site ID":"string", 
                        })
wq_raw["Submission Date"]=pd.to_datetime(wq_raw["Submission Date"])
print(wq_raw.dtypes)
# Out:
# Case Number                string
# Scientist                  string
# Matrix                     string
# Project Name               string
# Submission Date    datetime64[ns]
# Comments                   string
# Units                      string
# Sample Number              string
# Site ID                    string
# Bottle No                 float64
# NO3-N                      object
# dtype: object

# %% [markdown]
# **Change Blanks so conversion of datatypes later is correct**

# %%
wq_raw.loc[wq_raw["Site ID"] == "BLANK", "Site ID"] = "000000BL"

# %% [markdown]
# ### Separate Site ID Column into Separate Columns

# %%
wq_raw["Site ID"][0][0:1]
# Out:
# 'S'

# %%
wq_raw["Site Code"]= wq_raw["Site ID"].str.slice(0,2)
wq_raw["Year Code"]= wq_raw["Site ID"].str.slice(2,3)
wq_raw["DOY"]= wq_raw["Site ID"].str.slice(3,6)
wq_raw["Sample Location"]= wq_raw["Site ID"].str.slice(6,8)
wq_raw.head()
wq_raw[5:25]
# Out:
#    Case Number         Scientist Matrix Project Name Submission Date Comments  \
# 5      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 6      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 7      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 8      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 9      22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 10     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 11     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 12     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 13     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 14     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 15     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 16     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 17     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 18     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 19     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 20     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 21     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 22     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 23     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 24     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
#
#    Units Sample Number   Site ID  Bottle No  NO3-N Site Code Year Code  DOY  \
# 5   mg/L   22x0132-006  SH210106        6.0    1.9        SH         2  101
# 6   mg/L   22x0132-007  SH2101BX        7.0   11.2        SH         2  101
# 7   mg/L   22x0132-008  SH2101CK        8.0   13.6        SH         2  101
# 8   mg/L   22x0132-009  000000BL        9.0  < 0.3        00         0  000
# 9   mg/L   22x0167-001  SH211601        1.0    2.2        SH         2  116
# 10  mg/L   22x0167-002  SH211602        2.0    0.6        SH         2  116
# 11  mg/L   22x0167-003  SH211603        3.0  < 0.3        SH         2  116
# 12  mg/L   22x0167-004  SH211604        4.0    5.9        SH         2  116
# 13  mg/L   22x0167-005  SH211605        5.0    6.6        SH         2  116
# 14  mg/L   22x0167-006  SH211606        6.0      4        SH         2  116
# 15  mg/L   22x0167-007  SH2116BX        7.0   18.9        SH         2  116
# 16  mg/L   22x0167-008  SH2116CK        8.0   13.8        SH         2  116
# 17  mg/L   22x0167-009  000000BL        9.0  < 0.3        00         0  000
# 18  mg/L   22x0211-001  SH212901        1.0    0.8        SH         2  129
# 19  mg/L   22x0211-002  SH212902        2.0  < 0.3        SH         2  129
# 20  mg/L   22x0211-003  SH212903        3.0  < 0.3        SH         2  129
# 21  mg/L   22x0211-004  SH212904        4.0    5.4        SH         2  129
# 22  mg/L   22x0211-005  SH212905        5.0    3.2        SH         2  129
# 23  mg/L   22x0211-006  SH212906        6.0    3.6        SH         2  129
# 24  mg/L   22x0211-007  SH2129BX        7.0   23.5        SH         2  129
#
#    Sample Location
# 5               06
# 6               BX
# 7               CK
# 8               BL
# 9               01
# 10              02
# 11              03
# 12              04
# 13              05
# 14              06
# 15              BX
# 16              CK
# 17              BL
# 18              01
# 19              02
# 20              03
# 21              04
# 22              05
# 23              06
# 24              BX

# %%
wq_raw.dtypes
# Out:
# Case Number                string
# Scientist                  string
# Matrix                     string
# Project Name               string
# Submission Date    datetime64[ns]
# Comments                   string
# Units                      string
# Sample Number              string
# Site ID                    string
# Bottle No                 float64
# NO3-N                      object
# Site Code                  string
# Year Code                  string
# DOY                        string
# Sample Location            string
# dtype: object

# %%
wq_raw["DOY"] = wq_raw["DOY"].astype(int)
# Out:
#    Case Number         Scientist Matrix Project Name Submission Date Comments  \
# 5      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 6      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 7      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 8      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 9      22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 10     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 11     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 12     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 13     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 14     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 15     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 16     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 17     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 18     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 19     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 20     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 21     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 22     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 23     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 24     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
#
#    Units Sample Number   Site ID  Bottle No  NO3-N Site Code Year Code  DOY  \
# 5   mg/L   22x0132-006  SH210106        6.0    1.9        SH         2  101
# 6   mg/L   22x0132-007  SH2101BX        7.0   11.2        SH         2  101
# 7   mg/L   22x0132-008  SH2101CK        8.0   13.6        SH         2  101
# 8   mg/L   22x0132-009  000000BL        9.0  < 0.3        00         0    0
# 9   mg/L   22x0167-001  SH211601        1.0    2.2        SH         2  116
# 10  mg/L   22x0167-002  SH211602        2.0    0.6        SH         2  116
# 11  mg/L   22x0167-003  SH211603        3.0  < 0.3        SH         2  116
# 12  mg/L   22x0167-004  SH211604        4.0    5.9        SH         2  116
# 13  mg/L   22x0167-005  SH211605        5.0    6.6        SH         2  116
# 14  mg/L   22x0167-006  SH211606        6.0      4        SH         2  116
# 15  mg/L   22x0167-007  SH2116BX        7.0   18.9        SH         2  116
# 16  mg/L   22x0167-008  SH2116CK        8.0   13.8        SH         2  116
# 17  mg/L   22x0167-009  000000BL        9.0  < 0.3        00         0    0
# 18  mg/L   22x0211-001  SH212901        1.0    0.8        SH         2  129
# 19  mg/L   22x0211-002  SH212902        2.0  < 0.3        SH         2  129
# 20  mg/L   22x0211-003  SH212903        3.0  < 0.3        SH         2  129
# 21  mg/L   22x0211-004  SH212904        4.0    5.4        SH         2  129
# 22  mg/L   22x0211-005  SH212905        5.0    3.2        SH         2  129
# 23  mg/L   22x0211-006  SH212906        6.0    3.6        SH         2  129
# 24  mg/L   22x0211-007  SH2129BX        7.0   23.5        SH         2  129
#
#    Sample Location
# 5               06
# 6               BX
# 7               CK
# 8               BL
# 9               01
# 10              02
# 11              03
# 12              04
# 13              05
# 14              06
# 15              BX
# 16              CK
# 17              BL
# 18              01
# 19              02
# 20              03
# 21              04
# 22              05
# 23              06
# 24              BX

# %% [markdown]
# **Create Sample Date Column**

# %%
MMDD = "01/01"
YY = wq_raw["Year Code"][0]+wq_raw["Year Code"][1] # Use the first and second rows as a check
first_day_of_year = MMDD+"/"+YY
print(first_day_of_year)
# Out:
# 01/01/22

# %%
first_day_of_year = pd.to_datetime(first_day_of_year)

# %%
wq_raw["Sample Date"] = first_day_of_year
wq_raw["Sample Date"] = wq_raw["Sample Date"] + pd.to_timedelta((wq_raw["DOY"]-1), unit="d")
#first_day_of_year + dt.timedelta(days = wq_raw["DOY"])
wq_raw.head()
# Out:
#   Case Number         Scientist Matrix Project Name Submission Date Comments  \
# 0     22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 1     22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 2     22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 3     22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 4     22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
#
#   Units Sample Number   Site ID  Bottle No  NO3-N Site Code Year Code  DOY  \
# 0  mg/L   22x0132-001  SH210101        1.0    3.3        SH         2  101
# 1  mg/L   22x0132-002  SH210102        2.0    0.4        SH         2  101
# 2  mg/L   22x0132-003  SH210103        3.0  < 0.3        SH         2  101
# 3  mg/L   22x0132-004  SH210104        4.0    6.1        SH         2  101
# 4  mg/L   22x0132-005  SH210105        5.0    5.8        SH         2  101
#
#   Sample Location Sample Date
# 0              01  2022-04-11
# 1              02  2022-04-11
# 2              03  2022-04-11
# 3              04  2022-04-11
# 4              05  2022-04-11

# %%
wq_raw[5:25]
# Out:
#    Case Number         Scientist Matrix Project Name Submission Date Comments  \
# 5      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 6      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 7      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 8      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 9      22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 10     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 11     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 12     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 13     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 14     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 15     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 16     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 17     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 18     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 19     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 20     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 21     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 22     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 23     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
# 24     22x0211  Natalia Rogovska  Water      Shearer      2022-05-13     <NA>
#
#    Units Sample Number   Site ID  Bottle No  NO3-N Site Code Year Code  DOY  \
# 5   mg/L   22x0132-006  SH210106        6.0    1.9        SH         2  101
# 6   mg/L   22x0132-007  SH2101BX        7.0   11.2        SH         2  101
# 7   mg/L   22x0132-008  SH2101CK        8.0   13.6        SH         2  101
# 8   mg/L   22x0132-009  000000BL        9.0  < 0.3        00         0    0
# 9   mg/L   22x0167-001  SH211601        1.0    2.2        SH         2  116
# 10  mg/L   22x0167-002  SH211602        2.0    0.6        SH         2  116
# 11  mg/L   22x0167-003  SH211603        3.0  < 0.3        SH         2  116
# 12  mg/L   22x0167-004  SH211604        4.0    5.9        SH         2  116
# 13  mg/L   22x0167-005  SH211605        5.0    6.6        SH         2  116
# 14  mg/L   22x0167-006  SH211606        6.0      4        SH         2  116
# 15  mg/L   22x0167-007  SH2116BX        7.0   18.9        SH         2  116
# 16  mg/L   22x0167-008  SH2116CK        8.0   13.8        SH         2  116
# 17  mg/L   22x0167-009  000000BL        9.0  < 0.3        00         0    0
# 18  mg/L   22x0211-001  SH212901        1.0    0.8        SH         2  129
# 19  mg/L   22x0211-002  SH212902        2.0  < 0.3        SH         2  129
# 20  mg/L   22x0211-003  SH212903        3.0  < 0.3        SH         2  129
# 21  mg/L   22x0211-004  SH212904        4.0    5.4        SH         2  129
# 22  mg/L   22x0211-005  SH212905        5.0    3.2        SH         2  129
# 23  mg/L   22x0211-006  SH212906        6.0    3.6        SH         2  129
# 24  mg/L   22x0211-007  SH2129BX        7.0   23.5        SH         2  129
#
#    Sample Location Sample Date
# 5               06  2022-04-11
# 6               BX  2022-04-11
# 7               CK  2022-04-11
# 8               BL  2021-12-31
# 9               01  2022-04-26
# 10              02  2022-04-26
# 11              03  2022-04-26
# 12              04  2022-04-26
# 13              05  2022-04-26
# 14              06  2022-04-26
# 15              BX  2022-04-26
# 16              CK  2022-04-26
# 17              BL  2021-12-31
# 18              01  2022-05-09
# 19              02  2022-05-09
# 20              03  2022-05-09
# 21              04  2022-05-09
# 22              05  2022-05-09
# 23              06  2022-05-09
# 24              BX  2022-05-09

# %% [markdown]
# **Replace Nitrate Concentration values below detection limit with zero**

# %%
wq_raw["NO3-N"] = wq_raw["NO3-N"].astype(str)

# %%
wq_raw["NO3-N-clean"] = np.where(wq_raw["NO3-N"].str.contains("<"), "0.0", wq_raw["NO3-N"])
wq_raw["NO3-N-clean"] = wq_raw["NO3-N-clean"].astype(float)
wq_raw[5:15]
# Out:
#    Case Number         Scientist Matrix Project Name Submission Date Comments  \
# 5      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 6      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 7      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 8      22x0132  Natalia Rogovska  Water      Shearer      2022-04-12     <NA>
# 9      22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 10     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 11     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 12     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 13     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
# 14     22x0167  Natalia Rogovska  Water      Shearer      2022-04-28     <NA>
#
#    Units Sample Number   Site ID  Bottle No  NO3-N Site Code Year Code  DOY  \
# 5   mg/L   22x0132-006  SH210106        6.0    1.9        SH         2  101
# 6   mg/L   22x0132-007  SH2101BX        7.0   11.2        SH         2  101
# 7   mg/L   22x0132-008  SH2101CK        8.0   13.6        SH         2  101
# 8   mg/L   22x0132-009  000000BL        9.0  < 0.3        00         0    0
# 9   mg/L   22x0167-001  SH211601        1.0    2.2        SH         2  116
# 10  mg/L   22x0167-002  SH211602        2.0    0.6        SH         2  116
# 11  mg/L   22x0167-003  SH211603        3.0  < 0.3        SH         2  116
# 12  mg/L   22x0167-004  SH211604        4.0    5.9        SH         2  116
# 13  mg/L   22x0167-005  SH211605        5.0    6.6        SH         2  116
# 14  mg/L   22x0167-006  SH211606        6.0      4        SH         2  116
#
#    Sample Location Sample Date  NO3-N-clean
# 5               06  2022-04-11          1.9
# 6               BX  2022-04-11         11.2
# 7               CK  2022-04-11         13.6
# 8               BL  2021-12-31          0.0
# 9               01  2022-04-26          2.2
# 10              02  2022-04-26          0.6
# 11              03  2022-04-26          0.0
# 12              04  2022-04-26          5.9
# 13              05  2022-04-26          6.6
# 14              06  2022-04-26          4.0

# %% [markdown]
# ### Create Final Clean NO3-N Concentration Dataset

# %%
wq_clean = wq_raw[["Sample Date", "Site ID", "Site Code", "Sample Location", "NO3-N-clean"]]
wq_clean
# Out:
#     Sample Date   Site ID Site Code Sample Location  NO3-N-clean
# 0    2022-04-11  SH210101        SH              01       3.3000
# 1    2022-04-11  SH210102        SH              02       0.4000
# 2    2022-04-11  SH210103        SH              03       0.0000
# 3    2022-04-11  SH210104        SH              04       6.1000
# 4    2022-04-11  SH210105        SH              05       5.8000
# ..          ...       ...       ...             ...          ...
# 103  2022-08-05  SH221704        SH              04      15.2390
# 104  2022-08-05  SH221705        SH              05      16.0490
# 105  2022-08-05  SH221706        SH              06       9.5212
# 106  2022-08-05  SH2217BX        SH              BX      19.4780
# 107  2022-08-05  SH2217CK        SH              CK       8.5377
#
# [108 rows x 5 columns]

# %%
wq_clean.to_csv("no3_conc.csv", index = False)
